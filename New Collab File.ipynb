# %% [markdown]
# # Empty Shelf Detection using Custom R-CNN
# This notebook implements the Empty Shelf Detection pipeline using a custom R-CNN architecture.
# Follow the steps to train and test the model effectively.

# %%
# Install dependencies
# !pip install tensorflow pandas opencv-python

# %% [markdown]
# ### Upload Required Files
# Upload the following files to Colab in this step:
# - `converter.py`
# - `DataAugmentationHelper.py`
# - `EmptyShelfDetectionCustomRCNN.py`
# - `RCNNModel.py`
# - `main.py`

# %%
from google.colab import files

# Upload required files
uploaded = files.upload()

# Move the uploaded files to the working directory
for file_name in uploaded.keys():
    print(f"Uploaded: {file_name}")
# Out:
#      <input type="file" id="files-0ff459ac-a589-4e6f-aa24-b4dad9296206" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ff459ac-a589-4e6f-aa24-b4dad9296206">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Execute the main script
# !python EmptyShelfDetectionCustomRCNN.py --annotations_dir "drive/MyDrive/Dataset/EMPTY SHELF FINAL/EMPTY SHELF FINAL/train/labelTxt" --image_folder "drive/MyDrive/Dataset/EMPTY SHELF FINAL/EMPTY SHELF FINAL/train/images" --epochs 40 --batch_size 16
# Out:
# 2024-11-29 17:29:32.530074: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-29 17:29:32.549239: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-29 17:29:32.555025: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-29 17:29:32.568941: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python main.py
# Out:
# 2024-11-25 19:26:36.349971: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-25 19:26:36.369792: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-25 19:26:36.375921: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-25 19:26:36.390095: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
